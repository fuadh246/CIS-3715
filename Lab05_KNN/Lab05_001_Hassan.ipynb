# %% [markdown]
# # Lab 5: KNN

# %% [markdown]
# In this assignment, we will learn the KNN model.
#
# First, please study the given example, which uses the KNN model for the breast cancer classification task. In this example, you will learn how to preprocess data, how to train the model, and how to evaluate the model.
#
# Based on the given example, your task is to use the KNN model to predict the presence of heart disease.

# %% [markdown]
# ## 1. Example

# %% [markdown]
# ### 1.1 Load the breast cancer data

# %% [markdown]
# Here, we use the [breast cancer](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_breast_cancer.html#sklearn.datasets.load_breast_cancer) dataset in sklearn. It is a binary classification dataset. Each sample has 30 numerical features, which can be found in [7.1.7](https://scikit-learn.org/stable/datasets/toy_dataset.html).

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, f1_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from random import shuffle
import random
random.seed(123)

X, y = datasets.load_breast_cancer(return_X_y=True)
print("#samples: {}, #features: {}".format(X.shape[0], X.shape[1]))
# Out:
# #samples: 569, #features: 30

# %% [markdown]
# ### 1.2 Split the data into two subsets and normalize the features of samples
#
# Here, we use 69 samples as the testing set and use the remained samples to train the logistic regression model.

# %%
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y,
                                                            test_size=0.12,
                                                            random_state=0)
print("train_val: {}, test: {}".format(X_train_val.shape[0], X_test.shape[0]))

normalizer = StandardScaler()
X_train_val = normalizer.fit_transform(X_train_val)
X_test = normalizer.transform(X_test)
# Out:
# train_val: 500, test: 69

# %% [markdown]
# ### 1.3 Train the KNN model and select the hyperparameter with cross-validation
#
# Here, we use cross-validation to select the hyperparameter $K$

# %%
k_range = range(1, 5)
param_grid = dict(n_neighbors=k_range)

clf_knn = KNeighborsClassifier(n_neighbors=1)

grid = GridSearchCV(clf_knn, param_grid, cv=5, scoring='accuracy')
grid.fit(X_train_val, y_train_val)

print(grid.best_score_)
print(grid.best_params_)
# Out:
# 0.9640000000000001
# {'n_neighbors': 4}

# %% [markdown]
# ### 1.4 Evaluate the learned model
#
# After getting the best hyperparameter $K$,  we evaluate this  model on the testing set.

# %%
clf_knn = KNeighborsClassifier(n_neighbors=grid.best_params_['n_neighbors'])
clf_knn.fit(X_train_val, y_train_val)

# evaluate the model on the testing set
y_test_pred = clf_knn.predict(X_test)


acc = accuracy_score(y_test, y_test_pred)
f1 = f1_score(y_test, y_test_pred)
recall = recall_score(y_test, y_test_pred)
precision = precision_score(y_test, y_test_pred)


print("accuracy: {:.3f}, recall: {:.3f}, precision: {:.3f}, f1: {:.3f},".format(
    acc, recall, precision, f1))
# Out:
# accuracy: 0.971, recall: 0.975, precision: 0.975, f1: 0.975,

# %% [markdown]
# ## 2. Task
#
# Here, we use the [heart disease](./heart.csv) dataset. Each sample has the following feature:
#
# * age
# * sex
# * chest pain type (4 values)
# * resting blood pressure
# * serum cholestoral in mg/dl
# * fasting blood sugar > 120 mg/dl
# * resting electrocardiographic results (values 0,1,2)
# * maximum heart rate achieved
# * exercise induced angina
# * oldpeak = ST depression induced by exercise relative to rest
# * the slope of the peak exercise ST segment
# * number of major vessels (0-3) colored by flourosopy
# * thal: 3 = normal; 6 = fixed defect; 7 = reversable defect
#
# The last column refers to the presence of heart disease in the patient.
#
# The task is to predict whether a person has the heart disease. Here, you can use your code in Lab04 for Task 2.1 and Task 2.2.

# %% [markdown]
# ### 2.1 Preprocess the raw data
#
# * Check whether there are missing values
# * Check whether theare are cateogrical features
# * Check whether this dataset is balanced or not (use the bar plot to visualize the number of positive and negative samples)

# %%
# your code
df = pd.read_csv('../Data/heart.csv')
print("#samples: {}, #features: {}".format(df.shape[0], df.shape[1]))
# Out:
# #samples: 303, #features: 14

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T
col2 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_0bf4b_row3_col2, #T_0bf4b_row6_col7 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_0bf4b_row3_col4 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_0bf4b_row3_col5 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_0bf4b_row3_col6, #T_0bf4b_row11_col13 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_0bf4b_row3_col8, #T_0bf4b_row4_col8, #T_0bf4b_row5_col2 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_0bf4b_row3_col9 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_0bf4b_row3_col10 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_0bf4b_row3_col11, #T_0bf4b_row8_col0 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_0bf4b_row3_col12 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_0bf4b_row3_col13, #T_0bf4b_row6_col0, #T_0bf4b_row8_col10 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_0bf4b_row4_col0 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_0bf4b_row4_col1, #T_0bf4b_row12_col13 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_0bf4b_row4_col2, #T_0bf4b_row6_col11 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_0bf4b_row4_col5, #T_0bf4b_row13_col9 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_0bf4b_row4_col7, #T_0bf4b_row5_col7 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_0bf4b_row4_col9, #T_0bf4b_row6_col13 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_0bf4b_row4_col11, #T_0bf4b_row12_col0 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_0bf4b_row4_col12, #T_0bf4b_row5_col10, #T_0bf4b_row6_col9, #T_0bf4b_row8_col1 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_0bf4b_row4_col13 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_0bf4b_row5_col1, #T_0bf4b_row6_col8 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_0bf4b_row5_col3, #T_0bf4b_row5_col13 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_0bf4b_row5_col4, #T_0bf4b_row10_col12 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_0bf4b_row5_col6, #T_0bf4b_row13_col5 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_0bf4b_row5_col8 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_0bf4b_row5_col11 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_0bf4b_row6_col2, #T_0bf4b_row11_col10 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_0bf4b_row6_col3 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_0bf4b_row6_col4, #T_0bf4b_row7_col8 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_0bf4b_row6_col10 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_0bf4b_row7_col1, #T_0bf4b_row7_col12, #T_0bf4b_row8_col3 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_0bf4b_row7_col2 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_0bf4b_row7_col3, #T_0bf4b_row9_col5 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_0bf4b_row7_col4 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_0bf4b_row7_col5, #T_0bf4b_row8_col6, #T_0bf4b_row11_col6 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_0bf4b_row7_col10 {
#   background-color: #3d93c2;
#   color: #f1f1f1;
# }
# #T_0bf4b_row7_col11 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_0bf4b_row7_col13, #T_0bf4b_row13_col2 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_0bf4b_row8_col4 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_0bf4b_row8_col7 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_0bf4b_row8_col9 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_0bf4b_row8_col12 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_0bf4b_row9_col0 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_0bf4b_row9_col1, #T_0bf4b_row9_col3 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_0bf4b_row9_col7 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_0bf4b_row9_col8, #T_0bf4b_row11_col9 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_0bf4b_row9_col13 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_0bf4b_row10_col1 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_0bf4b_row10_col3, #T_0bf4b_row10_col5 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_0bf4b_row10_col4 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_0bf4b_row10_col7 {
#   background-color: #569dc8;
#   color: #f1f1f1;
# }
# #T_0bf4b_row10_col8, #T_0bf4b_row13_col0

# %%
df.groupby('target').sum()
# Out:
#          age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  \
# target
# 0       7811  114   66     18547  34650   22       62    19196     76
# 1       8662   93  227     21335  39968   23       98    26147     23
#
#         oldpeak  slope   ca  thal
# target
# 0         218.8    161  161   351
# 1          96.2    263   60   350

# %%
sum__by_credit_score = df.groupby('target')['sex'].sum().reset_index()
sns.barplot(x='target', y='sex', data=sum__by_credit_score, hue='sex',
            palette='viridis', width=.5)
plt.show()

# %%
balance_counts = df['target'].value_counts()
balance_counts
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
sns.barplot(x=balance_counts.index, y=balance_counts.values,
            palette=['green', 'red'], width=.5)
plt.xlabel('Target')
plt.ylabel('Number of samples')
plt.title('Distribution')
plt.xticks(ticks=[0, 1], labels=["No Heart Disease", "Heart Disease"])
plt.show()

# %% [markdown]
# ### 2.2 Split the data into two subsets and normalize the features of samples
#
# * Split the dataset into the train_val set and testing set.
# * Normalize features

# %%
X = df.drop('target', axis=1).values
Y = df['target'].values

# %%
# your code
X_train_val, X_test, y_train_val, y_test = train_test_split(X, Y,
                                                            test_size=0.2,
                                                            random_state=0)
print("train_val: {}, test: {}".format(X_train_val.shape[0], X_test.shape[0]))

normalizer = StandardScaler()
X_train_val = normalizer.fit_transform(X_train_val)
X_test = normalizer.transform(X_test)
# Out:
# train_val: 242, test: 61

# %% [markdown]
# ### 2.3 Train the KNN model and select the hyperparameter with cross-validation
#
#
# * Use the 5-fold cross-validation to select the hyperparameter $K$.
# * Search $K$ from $\{1, 2, 3, 4, 5\}$

# %%
# your code
k_range = range(1, 5)
param_grid = dict(n_neighbors=k_range)

clf_knn = KNeighborsClassifier(n_neighbors=1)

grid = GridSearchCV(clf_knn, param_grid, cv=5, scoring='accuracy')
grid.fit(X_train_val, y_train_val)

print(grid.best_score_)
print(grid.best_params_)
# Out:
# 0.8061224489795918
# {'n_neighbors': 4}

# %% [markdown]
# ### 2.4 Evaluate the learned model
#
# * Report the prediction accuracy, recall, precision, and F1 score.
#
# * Note that you should implement the code for these metrics by yourself. Please do NOT use the built-in function in sklearn.

# %%
class ClassificationMetrics:
    def __init__(self, positive_label=1):
        self.positive_label = positive_label

    def accuracy(self, y_true, y_pred):
        correct = np.sum(y_true == y_pred)
        total = len(y_true)
        return correct/total

    def recall(self, y_true, y_pred):
        true_positive = np.sum((y_true == self.positive_label) & (
            y_pred == self.positive_label))
        actual_positive = np.sum(y_true == self.positive_label)
        return true_positive/actual_positive if actual_positive != 0 else 0

    def precision(self, y_true, y_pred):
        true_positive = np.sum((y_true == self.positive_label) & (
            y_pred == self.positive_label))
        predicted_positive = np.sum(y_pred == self.positive_label)
        return true_positive/predicted_positive if predicted_positive != 0 else 0

    def f1_score(self, y_true, y_pred):
        prec = self.precision(y_true, y_pred)
        rec = self.recall(y_true, y_pred)
        if prec + rec != 0:
            return 2 * (prec * rec)/(prec + rec)
        else:
            return 0

# %%
# your code
clf_knn = KNeighborsClassifier(n_neighbors=grid.best_params_['n_neighbors'])
clf_knn.fit(X_train_val, y_train_val)

# evaluate the model on the testing set
y_test_pred = clf_knn.predict(X_test)

metrics = ClassificationMetrics(positive_label=1)
print("Accuracy:", metrics.accuracy(y_test, y_test_pred))
print("Recall:", metrics.recall(y_test, y_test_pred))
print("Precision:", metrics.precision(y_test, y_test_pred))
print("F1 Score:", metrics.f1_score(y_test, y_test_pred))
# Out:
# Accuracy: 0.8524590163934426
# Recall: 0.8529411764705882
# Precision: 0.8787878787878788
# F1 Score: 0.8656716417910447
